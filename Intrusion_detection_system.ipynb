# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from tqdm import tqdm
# Out:
# C:\Users\Harsh\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train=pd.read_csv(r"UNSW_NB15_training-set.csv", na_values=["-"])  # service column contains "-" so to replace it with NaN, na_values is used 
train
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp     NaN   INT      2      0     496       0
# 1          2  0.000008   udp     NaN   INT      2      0    1762       0
# 2          3  0.000005   udp     NaN   INT      2      0    1068       0
# 3          4  0.000006   udp     NaN   INT      2      0     900       0
# 4          5  0.000010   udp     NaN   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp     NaN   INT      2      0     104       0
# 82328  82329  1.106101   tcp     NaN   FIN     20      8   18062     354
# 82329  82330  0.000000   arp     NaN   INT      1      0      46       0
# 82330  82331  0.000000   arp     NaN   INT      1      0      46       0
# 82331  82332  0.000009   udp     NaN   INT      2      0     104       0
#
#                 rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0       90909.090200  ...                 1               2             0
# 1      125000.000300  ...                 1               2             0
# 2      200000.005100  ...                 1               3             0
# 3      166666.660800  ...                 1               3             0
# 4      100000.002500  ...                 1               3             0
# ...              ...  ...               ...             ...           ...
# 82327  200000.005100  ...                 1               2             0
# 82328      24.410067  ...                 1               1             0
# 82329       0.000000  ...                 1               1             0
# 82330       0.000000  ...                 1               1             0
# 82331  111111.107200  ...                 1               1             0
#
#        ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0               0                 0           1           2                0
# 1               0                 0           1           2                0
# 2               0                 0           1           3                0
# 3               0                 0           2           3                0
# 4               0                 0           2           3                0
# ...           ...               ...         ...         ...              ...
# 82327           0                 0           2           1                0
# 82328           0                 0           3           2                0
# 82329           0                 0           1           1                1
# 82330           0                 0           1           1                1
# 82331           0                 0           1           1                0
#
#        attack_cat  label
# 0          Normal      0
# 1          Normal      0
# 2          Normal      0
# 3          Normal      0
# 4          Normal      0
# ...           ...    ...
# 82327      Normal      0
# 82328      Normal      0
# 82329      Normal      0
# 82330      Normal      0
# 82331      Normal      0
#
# [82332 rows x 45 columns]

# %%
train.columns
# Out:
# Index(['id', 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label'],
#       dtype='object')

# %%
total = len(train)*1.
ax=sns.countplot(x="label", data=train)
# for p in ax.patches:
#     print(p)
#     ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.3, p.get_height()+5))

# #put 11 ticks (therefore 10 steps), from 0 to the total number of rows in the dataframe
ax.yaxis.set_ticks(np.linspace(0, total, 11))
# print(ax.yaxis.get_majorticklocs())
# #adjust the ticklabel to the desired format, without changing the position of the ticks. 
# ax.set_yticklabels(map('{:.1f}%'.format, 100*ax.yaxis.get_majorticklocs()/total))
# plt.savefig('class_label.png')
plt.show()

# %%
cat_feature = train.select_dtypes(include=['category', object]).columns
cat_feature
# Out:
# Index(['proto', 'service', 'state', 'attack_cat'], dtype='object')

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 10))
plt.subplots_adjust(hspace = 0.4)
for col, subplot in zip(cat_feature, ax.flatten()):
    sns.countplot(train[col], ax=subplot)
    for labelx, labely in zip(subplot.get_xticklabels(), subplot.get_yticklabels()):
            labelx.set_rotation(45)
            labely.set_rotation(35) 
plt.show()


# for col in cat_feature:
#     sns.countplot(train[col],data=train)
#     plt.show()

# %% [markdown]
# # 3.2 visualizing numerical data and its distribution

# %%
num_features = train.drop(['id','label'], axis=1).select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns
print(num_features)
print(num_features.size)
# Out:
# Index(['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl',
#        'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit',
#        'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat', 'smean',
#        'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src',
#        'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm',
#        'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd',
#        'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports'],
#       dtype='object')
# 39

# %%
 fig, ax = plt.subplots(20, 2, figsize=(30, 50))
 plt.subplots_adjust(hspace = 0.4)
 for col, splot in zip(num_features, ax.flatten()):
     sns.distplot(train[col], ax=splot)
 plt.savefig('num_f.png')
 plt.show()

# %% [markdown]
# ## 3.3 Correlation of data .. discards object (categorical) data .. only accepts integer or float

# %%
train_corr = train.corr()  
print(type(train_corr))
train_corr.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# id                   float64
# dur                  float64
# spkts                float64
# dpkts                float64
# sbytes               float64
# dbytes               float64
# rate                 float64
# sttl                 float64
# dttl                 float64
# sload                float64
# dload                float64
# sloss                float64
# dloss                float64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                 float64
# stcpb                float64
# dtcpb                float64
# dwin                 float64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                float64
# dmean                float64
# trans_depth          float64
# response_body_len    float64
# ct_srv_src           float64
# ct_state_ttl         float64
# ct_dst_ltm           float64
# ct_src_dport_ltm     float64
# ct_dst_sport_ltm     float64
# ct_dst_src_ltm       float64
# is_ftp_login         float64
# ct_ftp_cmd           float64
# ct_flw_http_mthd     float64
# ct_src_ltm           float64
# ct_srv_dst           float64
# is_sm_ips_ports      float64
# label                float64
# dtype: object

# %%
train_corr = train.corr()

# %%
plt.figure(figsize=(30,20))
sns.heatmap(train_corr, annot=True)
plt.savefig('corr_mat.png')
plt.show()

# %% [markdown]
# # from here

# %%
high_corr_var=np.where(train_corr>0.95)

# %%
high_corr_var
# Out:
# (array([ 0,  1,  2,  2,  2,  3,  3,  3,  4,  4,  4,  5,  5,  5,  6,  7,  8,
#          9, 10, 11, 11, 11, 12, 12, 12, 13, 14, 15, 16, 17, 17, 18, 19, 20,
#         20, 21, 22, 23, 24, 25, 26, 27, 28, 28, 28, 29, 30, 30, 31, 31, 32,
#         33, 33, 33, 34, 34, 35, 35, 36, 37, 38, 38, 38, 39, 40],
#        dtype=int64),
#  array([ 0,  1,  2,  4, 11,  3,  5, 12,  2,  4, 11,  3,  5, 12,  6,  7,  8,
#          9, 10,  2,  4, 11,  3,  5, 12, 13, 14, 15, 16, 17, 20, 18, 19, 17,
#         20, 21, 22, 23, 24, 25, 26, 27, 28, 33, 38, 29, 30, 31, 30, 31, 32,
#         28, 33, 38, 34, 35, 34, 35, 36, 37, 28, 33, 38, 39, 40],
#        dtype=int64))

# %%
temp = []
for x, y in zip(*high_corr_var):
    if x!=y and x<y:
        print(train_corr.columns[x], train_corr.columns[y])
        temp.append((train_corr.columns[x],train_corr.columns[y]))
high_corr_var=temp
# Out:
# spkts sbytes
# spkts sloss
# dpkts dbytes
# dpkts dloss
# sbytes sloss
# dbytes dloss
# swin dwin
# ct_srv_src ct_dst_src_ltm
# ct_srv_src ct_srv_dst
# ct_dst_ltm ct_src_dport_ltm
# ct_dst_src_ltm ct_srv_dst
# is_ftp_login ct_ftp_cmd

# %%
high_corr_var
# Out:
# [('spkts', 'sbytes'),
#  ('spkts', 'sloss'),
#  ('dpkts', 'dbytes'),
#  ('dpkts', 'dloss'),
#  ('sbytes', 'sloss'),
#  ('dbytes', 'dloss'),
#  ('swin', 'dwin'),
#  ('ct_srv_src', 'ct_dst_src_ltm'),
#  ('ct_srv_src', 'ct_srv_dst'),
#  ('ct_dst_ltm', 'ct_src_dport_ltm'),
#  ('ct_dst_src_ltm', 'ct_srv_dst'),
#  ('is_ftp_login', 'ct_ftp_cmd')]

# %% [markdown]
# # # till here .. whats use

# %% [markdown]
# ## sbytes , sloss , spkts

# %%
print(train[['sbytes','sloss','spkts']].corr())        # ??????????????  why these 3
# Out:
#           sbytes     sloss     spkts
# sbytes  1.000000  0.996109  0.963791
# sloss   0.996109  1.000000  0.971069
# spkts   0.963791  0.971069  1.000000

# %%
sns.heatmap(train[['sbytes','sloss','spkts']].corr(), annot=True)
plt.show()

# %% [markdown]
# - so we can drop column sbyte from above representation.
# - From this visualization we can see that both have high correlation and same distribution with other columns

# %% [markdown]
# ## dbytes     dloss     dpkts

# %%
print(train[['dbytes','dloss','dpkts']].corr())
# Out:
#           dbytes     dloss     dpkts
# dbytes  1.000000  0.996504  0.971907
# dloss   0.996504  1.000000  0.978636
# dpkts   0.971907  0.978636  1.000000

# %%
sns.heatmap(train[['dbytes','dloss','dpkts']].corr(), annot=True)
plt.show()

# %% [markdown]
# - so we can drop column dbytes from above representation.
# - From this visualization we can see that both have high correlation and same distribution with other columns

# %% [markdown]
# ## ct_dst_src_ltm  ct_srv_src  ct_srv_dst

# %%
print(train[['ct_dst_src_ltm','ct_srv_src','ct_srv_dst']].corr())
# Out:
#                 ct_dst_src_ltm  ct_srv_src  ct_srv_dst
# ct_dst_src_ltm        1.000000    0.967138    0.972370
# ct_srv_src            0.967138    1.000000    0.980323
# ct_srv_dst            0.972370    0.980323    1.000000

# %%
obj=sns.heatmap(train[['ct_dst_src_ltm','ct_srv_src','ct_srv_dst']].corr(), annot=True)
for labelx, labely in zip(obj.get_xticklabels(), obj.get_yticklabels()):
    labelx.set_rotation(15)
    labely.set_rotation(0)
plt.show()

# %% [markdown]
# - we can drop column ct_srv_dst
# - From this visualization we can see that three columns are having high correlation and same distribution

# %% [markdown]
# ## swin     dwin

# %%
print(train[['swin','dwin']].corr())
# Out:
#          swin     dwin
# swin  1.00000  0.99014
# dwin  0.99014  1.00000

# %%
obj=sns.heatmap(train[['swin', 'dwin']].corr(), annot=True)
for labelx, labely in zip(obj.get_xticklabels(), obj.get_yticklabels()):
    labelx.set_rotation(15)
    labely.set_rotation(0)
plt.show()

# %% [markdown]
# ## is_ftp_login  ct_ftp_cmd

# %%
print(train[['is_ftp_login','ct_ftp_cmd']].corr())
# Out:
#               is_ftp_login  ct_ftp_cmd
# is_ftp_login           1.0         1.0
# ct_ftp_cmd             1.0         1.0

# %%
obj=sns.heatmap(train[['is_ftp_login', 'ct_ftp_cmd']].corr(), annot=True)
for labelx, labely in zip(obj.get_xticklabels(), obj.get_yticklabels()):
    labelx.set_rotation(15)
    labely.set_rotation(0)
plt.show()

# %% [markdown]
# - we can drop ct_ftp_cmd.
# - From this visualization we can see that both have high correlation and same distribution

# %% [markdown]
# # 3.5 EDA conclusion

# %% [markdown]
# #### we can drop the 5 columns mentioned from above analysis which are highly correlated
# - sbyte and dbytes
# - ct_srv_dst
# - ct_ftp_cmd
# - dwin

# %%
cols_to_drop = ['sbytes', 'dbytes','ct_srv_dst', 'ct_ftp_cmd', 'dwin']

# %%
train.drop(columns=cols_to_drop, inplace=True)
train.shape
# Out:
# (175341, 40)

# %%
test=pd.read_csv(r"UNSW_NB15_testing-set.csv", na_values=["-"])
test
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.121478   tcp     NaN   FIN      6      4     258     172
# 1            2  0.649902   tcp     NaN   FIN     14     38     734   42014
# 2            3  1.623129   tcp     NaN   FIN      8     16     364   13186
# 3            4  1.681642   tcp     ftp   FIN     12     12     628     770
# 4            5  0.449454   tcp     NaN   FIN     10      6     534     268
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175337  175338  0.505762   tcp     NaN   FIN     10      8     620     354
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0           74.087490  ...                 1               1             0
# 1           78.473372  ...                 1               2             0
# 2           14.170161  ...                 1               3             0
# 3           13.677108  ...                 1               3             1
# 4           33.373826  ...                 1              40             0
# ...               ...  ...               ...             ...           ...
# 175336  111111.107200  ...                13              24             0
# 175337      33.612649  ...                 1               2             0
# 175338  111111.107200  ...                 3              13             0
# 175339  111111.107200  ...                14              30             0
# 175340  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           1                0
# 1                0                 0           1           6                0
# 2                0                 0           2           6                0
# 3                1                 0           2           1                0
# 4                0                 0           2          39                0
# ...            ...               ...         ...         ...              ...
# 175336           0                 0          24          24                0
# 175337           0                 0           1           1                0
# 175338           0                 0           3          12                0
# 175339           0                 0          30          30                0
# 175340           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 175336     Generic      1
# 175337   Shellcode      1
# 175338     Generic      1
# 175339     Generic      1
# 175340     Generic      1
#
# [175341 rows x 45 columns]

# %%
print(train.shape, test.shape)
# Out:
# (175341, 40) (82332, 45)

# %%
test.drop(columns=cols_to_drop, inplace=True)
test.shape
# Out:
# (82332, 40)

# %%
df=pd.concat([train,test], sort=False, axis=0)
df
# Out:
#             id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0            1  0.000011   udp     NaN   INT      2      0     496       0
# 1            2  0.000008   udp     NaN   INT      2      0    1762       0
# 2            3  0.000005   udp     NaN   INT      2      0    1068       0
# 3            4  0.000006   udp     NaN   INT      2      0     900       0
# 4            5  0.000010   udp     NaN   INT      2      0    2126       0
# ...        ...       ...   ...     ...   ...    ...    ...     ...     ...
# 175336  175337  0.000009   udp     dns   INT      2      0     114       0
# 175337  175338  0.505762   tcp     NaN   FIN     10      8     620     354
# 175338  175339  0.000009   udp     dns   INT      2      0     114       0
# 175339  175340  0.000009   udp     dns   INT      2      0     114       0
# 175340  175341  0.000009   udp     dns   INT      2      0     114       0
#
#                  rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0        90909.090200  ...                 1               2             0
# 1       125000.000300  ...                 1               2             0
# 2       200000.005100  ...                 1               3             0
# 3       166666.660800  ...                 1               3             0
# 4       100000.002500  ...                 1               3             0
# ...               ...  ...               ...             ...           ...
# 175336  111111.107200  ...                13              24             0
# 175337      33.612649  ...                 1               2             0
# 175338  111111.107200  ...                 3              13             0
# 175339  111111.107200  ...                14              30             0
# 175340  111111.107200  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           1           2                0
# 1                0                 0           1           2                0
# 2                0                 0           1           3                0
# 3                0                 0           2           3                0
# 4                0                 0           2           3                0
# ...            ...               ...         ...         ...              ...
# 175336           0                 0          24          24                0
# 175337           0                 0           1           1                0
# 175338           0                 0           3          12                0
# 175339           0                 0          30          30                0
# 175340           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 175336     Generic      1
# 175337   Shellcode      1
# 175338     Generic      1
# 175339     Generic      1
# 175340     Generic      1
#
# [257673 rows x 45 columns]

# %%
def col_gen (labels, col_name, df):
    for label in labels:
        df[label]=np.where(df[col_name]==label,1,0)

# %%
df.isnull().sum()
# Out:
# id                        0
# dur                       0
# proto                     0
# service              141321
# state                     0
# spkts                     0
# dpkts                     0
# rate                      0
# sttl                      0
# dttl                      0
# sload                     0
# dload                     0
# sloss                     0
# dloss                     0
# sinpkt                    0
# dinpkt                    0
# sjit                      0
# djit                      0
# swin                      0
# stcpb                     0
# dtcpb                     0
# tcprtt                    0
# synack                    0
# ackdat                    0
# smean                     0
# dmean                     0
# trans_depth               0
# response_body_len         0
# ct_srv_src                0
# ct_state_ttl              0
# ct_dst_ltm                0
# ct_src_dport_ltm          0
# ct_dst_sport_ltm          0
# ct_dst_src_ltm            0
# is_ftp_login              0
# ct_flw_http_mthd          0
# ct_src_ltm                0
# is_sm_ips_ports           0
# attack_cat                0
# label                     0
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include=object).columns

# %%
for col in categorical_cols:
    print(df[col].value_counts())
# Out:
# tcp     123041
# udp      92701
# unas     15599
# arp       3846
# ospf      3271
#          ...
# hmp        131
# egp        131
# igmp        48
# icmp        15
# rtp          1
# Name: proto, Length: 133, dtype: int64
# dns         68661
# http        27011
# smtp         6909
# ftp-data     5391
# ftp          4980
# pop3         1528
# ssh          1506
# dhcp          120
# snmp          109
# ssl            86
# irc            30
# radius         21
# Name: service, dtype: int64
# FIN    117164
# INT    116438
# CON     20134
# REQ      3833
# RST        84
# ECO        12
# ACC         4
# CLO         1
# PAR         1
# no          1
# URN         1
# Name: state, dtype: int64
# Normal            93000
# Generic           58871
# Exploits          44525
# Fuzzers           24246
# DoS               16353
# Reconnaissance    13987
# Analysis           2677
# Backdoor           2329
# Shellcode          1511
# Worms               174
# Name: attack_cat, dtype: int64

# %%
services=df["service"].value_counts().head(7)#.index
print(services.dtype)
# Out:
# int64

# %%
print(df.shape)
# Out:
# (257673, 40)

# %%
col_gen(services,"service", df)

# %%
print(df.shape)
# Out:
# (257673, 47)

# %%
df.drop(labels="service", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 46)

# %%
states=df["state"].value_counts().head(4)#.index
print(states)
# Out:
# FIN    117164
# INT    116438
# CON     20134
# REQ      3833
# Name: state, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 46)

# %%
col_gen(states,"state", df)

# %%
print(df.shape)
# Out:
# (257673, 50)

# %%
df.drop(labels="state", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 49)

# %%
protocols=df["proto"].value_counts().head(6)#.index
print(protocols)
# Out:
# tcp     123041
# udp      92701
# unas     15599
# arp       3846
# ospf      3271
# sctp      1474
# Name: proto, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 49)

# %%
col_gen(protocols,"proto", df)

# %%
print(df.shape)
# Out:
# (257673, 55)

# %%
df.drop(labels="proto", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 54)

# %%
attack_cats=df["attack_cat"].value_counts().head(6)#.index
print(attack_cats)
# Out:
# Normal            93000
# Generic           58871
# Exploits          44525
# Fuzzers           24246
# DoS               16353
# Reconnaissance    13987
# Name: attack_cat, dtype: int64

# %%
print(df.shape)
# Out:
# (257673, 54)

# %%
col_gen(attack_cats,"attack_cat", df)

# %%
print(df.shape)
# Out:
# (257673, 60)

# %%
df.drop(labels="attack_cat", axis=1, inplace= True)

# %%
print(df.shape)
# Out:
# (257673, 59)

# %%
df.columns
# Out:
# Index([               'id',               'dur',             'spkts',
#                    'dpkts',              'rate',              'sttl',
#                     'dttl',             'sload',             'dload',
#                    'sloss',             'dloss',            'sinpkt',
#                   'dinpkt',              'sjit',              'djit',
#                     'swin',             'stcpb',             'dtcpb',
#                   'tcprtt',            'synack',            'ackdat',
#                    'smean',             'dmean',       'trans_depth',
#        'response_body_len',        'ct_srv_src',      'ct_state_ttl',
#               'ct_dst_ltm',  'ct_src_dport_ltm',  'ct_dst_sport_ltm',
#           'ct_dst_src_ltm',      'is_ftp_login',  'ct_flw_http_mthd',
#               'ct_src_ltm',   'is_sm_ips_ports',             'label',
#                      68661,               27011,                6909,
#                       5391,                4980,                1528,
#                       1506,              117164,              116438,
#                      20134,                3833,              123041,
#                      92701,               15599,                3846,
#                       3271,                1474,               93000,
#                      58871,               44525,               24246,
#                      16353,               13987],
#       dtype='object')

# %%
Y=df["label"]
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 82327    0
# 82328    0
# 82329    0
# 82330    0
# 82331    0
# Name: label, Length: 257673, dtype: int64

# %%
X = df.drop(labels="label", axis=1)

# %%
Y = Y.values.reshape(-1,1)

# %%
print(Y.shape)
# Out:
# (257673, 1)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X=ss.fit_transform(X)

# %%
print(X.shape, Y.shape)
# Out:
# (257673, 58) (257673, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25)

# %%
print(X_train.shape)
X_train
# Out:
# (193254, 58)
# array([[-1.20876841, -0.13122239,  0.7519323 , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.22849773, -0.20867891, -0.13076536, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.75273472, -0.01479691, -0.05720722, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.39742273,  0.15987813, -0.07191885, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.4030839 , -0.17684971, -0.07191885, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.94794588, -0.19759073, -0.02778397, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
print(Y_train.shape)
# Out:
# (193254, 1)

# %% [markdown]
# ## logistic regression

# %%
from sklearn.linear_model import LogisticRegression
log_clf = LogisticRegression(random_state=42)

# %%
log_clf.fit(X_train, Y_train)
y_pred=log_clf.predict(X_test)
y_pred = y_pred.reshape(-1, 1)
# Out:
# C:\Users\Piyush\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Piyush\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.metrics import f1_score
score = f1_score(Y_test, y_pred)
score
# Out:
# 0.9169052440472034

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[17886,  5354],
#        [ 1786, 39393]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accs=accuracy_score(Y_test,y_pred)
accs
# Out:
# 0.8890699948772878

# %% [markdown]
# ## SVM

# %% [markdown]
# from sklearn.svm import SVC
# svm_clf=SVC()

# %% [markdown]
# svm_clf.fit(X_train, Y_train)
# y_pred = svm_clf.predict(X_test)
# y_pred = y_pred.reshape(-1, 1)

# %% [markdown]
# from sklearn.metrics import f1_score
# score=f1_score(Y_test, y_pred)
# score

# %% [markdown]
# from sklearn.metrics import confusion_matrix
# cm=confusion_matrix(Y_test,y_pred)
# cm

# %% [markdown]
# from sklearn.metrics import accuracy_score
# accs=accuracy_score(Y_test,y_pred)
# accs

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

# %%
svm_clf = Pipeline((
("scaler", StandardScaler()),
("linear_svc", LinearSVC(C=1, loss="hinge")),
))

# %%
svm_clf.fit(X_train, Y_train)
# Out:
# C:\Users\Piyush\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Piyush\Anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear_svc', LinearSVC(C=1, loss='hinge'))])

# %%
y_pred=svm_clf.predict(X_test)
y_pred = y_pred.reshape(-1, 1)

# %%
from sklearn.metrics import f1_score
score1=f1_score(Y_test, y_pred)
score1
# Out:
# 0.9189409923092628

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[16767,  6473],
#        [  673, 40506]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accs1=accuracy_score(Y_test,y_pred)
accs1
# Out:
# 0.8890699948772878

# %% [markdown]
# ## Neural network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %% [markdown]
# we don't set conditions for input layer

# %%
classifier.add(Dense(units = 30, kernel_initializer = "he_uniform", input_dim = 58, activation = "relu"))      # 1st hidden layer
# Out:
# WARNING:tensorflow:From C:\Users\Piyush\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(units = 30, kernel_initializer = "he_uniform",activation = "relu"))    # 2nd hidden layer

# %%
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(units = 30, kernel_initializer = "he_uniform", activation = "relu"))    # 3rd hidden layer

# %%
classifier.add(Dense(units = 1, kernel_initializer = "glorot_uniform", activation = "sigmoid"))   # output layer   #activation = "softmax" if we had more than 2 classes in target

# %%
classifier.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])                    #loss = "categorical_crossentropy"  if more than 2 classes in target
# Out:
# WARNING:tensorflow:From C:\Users\Piyush\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
classifier.fit(X_train, Y_train, batch_size = 100, epochs = 10, validation_data=(X_test, Y_test))       #batch size tells that after training that many examples the parameters will be updated
# Out:
# Train on 193254 samples, validate on 64419 samples
# Epoch 1/10
# 193254/193254 [==============================] - ETA: 5:01 - loss: 0.7431 - acc: 0.550 - ETA: 10s - loss: 0.5974 - acc: 0.670 - ETA: 6s - loss: 0.5413 - acc: 0.7208 - ETA: 5s - loss: 0.5006 - acc: 0.749 - ETA: 4s - loss: 0.4733 - acc: 0.766 - ETA: 3s - loss: 0.4467 - acc: 0.782 - ETA: 3s - loss: 0.4237 - acc: 0.795 - ETA: 3s - loss: 0.4083 - acc: 0.804 - ETA: 2s - loss: 0.3917 - acc: 0.814 - ETA: 2s - loss: 0.3792 - acc: 0.820 - ETA: 2s - loss: 0.3712 - acc: 0.825 - ETA: 2s - loss: 0.3622 - acc: 0.830 - ETA: 2s - loss: 0.3545 - acc: 0.833 - ETA: 2s - loss: 0.3469 - acc: 0.837 - ETA: 2s - loss: 0.3400 - acc: 0.840 - ETA: 2s - loss: 0.3334 - acc: 0.844 - ETA: 1s - loss: 0.3276 - acc: 0.847 - ETA: 1s - loss: 0.3223 - acc: 0.850 - ETA: 1s - loss: 0.3184 - acc: 0.852 - ETA: 1s - loss: 0.3144 - acc: 0.854 - ETA: 1s - loss: 0.3104 - acc: 0.855 - ETA: 1s - loss: 0.3065 - acc: 0.857 - ETA: 1s - loss: 0.3028 - acc: 0.859 - ETA: 1s - loss: 0.3001 - acc: 0.860 - ETA: 1s - loss: 0.2971 - acc: 0.862 - ETA: 1s - loss: 0.2942 - acc: 0.863 - ETA: 1s - loss: 0.2910 - acc: 0.864 - ETA: 1s - loss: 0.2883 - acc: 0.865 - ETA: 1s - loss: 0.2854 - acc: 0.867 - ETA: 1s - loss: 0.2833 - acc: 0.868 - ETA: 1s - loss: 0.2814 - acc: 0.868 - ETA: 0s - loss: 0.2789 - acc: 0.870 - ETA: 0s - loss: 0.2767 - acc: 0.871 - ETA: 0s - loss: 0.2740 - acc: 0.872 - ETA: 0s - loss: 0.2722 - acc: 0.873 - ETA: 0s - loss: 0.2707 - acc: 0.873 - ETA: 0s - loss: 0.2692 - acc: 0.874 - ETA: 0s - loss: 0.2677 - acc: 0.874 - ETA: 0s - loss: 0.2662 - acc: 0.875 - ETA: 0s - loss: 0.2644 - acc: 0.876 - ETA: 0s - loss: 0.2629 - acc: 0.876 - ETA: 0s - loss: 0.2614 - acc: 0.877 - ETA: 0s - loss: 0.2601 - acc: 0.878 - ETA: 0s - loss: 0.2585 - acc: 0.878 - ETA: 0s - loss: 0.2573 - acc: 0.879 - ETA: 0s - loss: 0.2558 - acc: 0.879 - ETA: 0s - loss: 0.2543 - acc: 0.880 - ETA: 0s - loss: 0.2532 - acc: 0.880 - ETA: 0s - loss: 0.2519 - acc: 0.881 - 3s 16us/sample - loss: 0.2508 - acc: 0.8818 - val_loss: 0.1684 - val_acc: 0.9167
# Epoch 2/10
# 193254/193254 [==============================] - ETA: 11s - loss: 0.1609 - acc: 0.93 - ETA: 3s - loss: 0.1933 - acc: 0.9053 - ETA: 2s - loss: 0.1971 - acc: 0.904 - ETA: 2s - loss: 0.1989 - acc: 0.902 - ETA: 2s - loss: 0.1967 - acc: 0.903 - ETA: 2s - loss: 0.1942 - acc: 0.905 - ETA: 2s - loss: 0.1922 - acc: 0.906 - ETA: 2s - loss: 0.1911 - acc: 0.907 - ETA: 2s - loss: 0.1905 - acc: 0.906 - ETA: 2s - loss: 0.1894 - acc: 0.907 - ETA: 2s - loss: 0.1888 - acc: 0.908 - ETA: 1s - loss: 0.1876 - acc: 0.909 - ETA: 1s - loss: 0.1864 - acc: 0.909 - ETA: 1s - loss: 0.1859 - acc: 0.909 - ETA: 1s - loss: 0.1854 - acc: 0.909 - ETA: 1s - loss: 0.1847 - acc: 0.910 - ETA: 1s - loss: 0.1841 - acc: 0.910 - ETA: 1s - loss: 0.1844 - acc: 0.910 - ETA: 1s - loss: 0.1846 - acc: 0.910 - ETA: 1s - loss: 0.1838 - acc: 0.910 - ETA: 1s - loss: 0.1833 - acc: 0.910 - ETA: 1s - loss: 0.1827 - acc: 0.911 - ETA: 1s - loss: 0.1828 - acc: 0.911 - ETA: 1s - loss: 0.1819 - acc: 0.911 - ETA: 1s - loss: 0.1817 - acc: 0.911 - ETA: 1s - loss: 0.1821 - acc: 0.911 - ETA: 1s - loss: 0.1826 - acc: 0.911 - ETA: 1s - loss: 0.1821 - acc: 0.911 - ETA: 1s - loss: 0.1822 - acc: 0.911 - ETA: 1s - loss: 0.1824 - acc: 0.911 - ETA: 0s - loss: 0.1821 - acc: 0.911 - ETA: 0s - loss: 0.1814 - acc: 0.912 - ETA: 0s - loss: 0.1809 - acc: 0.912 - ETA: 0s - loss: 0.1804 - acc: 0.912 - ETA: 0s - loss: 0.1802 - acc: 0.912 - ETA: 0s - loss: 0.1799 - acc: 0.912 - ETA: 0s - loss: 0.1797 - acc: 0.913 - ETA: 0s - loss: 0.1795 - acc: 0.913 - ETA: 0s - loss: 0.1792 - acc: 0.913 - ETA: 0s - loss: 0.1787 - acc: 0.913 - ETA: 0s - loss: 0.1786 - acc: 0.913 - ETA: 0s - loss: 0.1784 - acc: 0.913 - ETA: 0s - loss: 0.1781 - acc: 0.914 - ETA: 0s - loss: 0.1779 - acc: 0.914 - ETA: 0s - loss: 0.1781 - acc: 0.914 - ETA: 0s - loss: 0.1777 - acc: 0.914 - ETA: 0s - loss: 0.1772 - acc: 0.914 - ETA: 0s - loss: 0.1770 - acc: 0.914 - ETA: 0s - loss: 0.1768 - acc: 0.915 - 3s 15us/sample - loss: 0.1766 - acc: 0.9150 - val_loss: 0.1475 - val_acc: 0.9284
# Epoch 3/10
# 193254/193254 [==============================] - ETA: 15s - loss: 0.1078 - acc: 0.95 - ETA: 2s - loss: 0.1599 - acc: 0.9258 - ETA: 2s - loss: 0.1605 - acc: 0.926 - ETA: 2s - loss: 0.1640 - acc: 0.925 - ETA: 2s - loss: 0.1641 - acc: 0.924 - ETA: 2s - loss: 0.1622 - acc: 0.924 - ETA: 2s - loss: 0.1622 - acc: 0.924 - ETA: 2s - loss: 0.1633 - acc: 0.924 - ETA: 2s - loss: 0.1645 - acc: 0.923 - ETA: 2s - loss: 0.1637 - acc: 0.923 - ETA: 2s - loss: 0.1634 - acc: 0.923 - ETA: 2s - loss: 0.1632 - acc: 0.923 - ETA: 2s - loss: 0.1639 - acc: 0.923 - ETA: 1s - loss: 0.1632 - acc: 0.923 - ETA: 1s - loss: 0.1635 - acc: 0.922 - ETA: 1s - loss: 0.1634 - acc: 0.923 - ETA: 1s - loss: 0.1632 - acc: 0.923 - ETA: 1s - loss: 0.1634 - acc: 0.923 - ETA: 1s - loss: 0.1632 - acc: 0.923 - ETA: 1s - loss: 0.1629 - acc: 0.923 - ETA: 1s - loss: 0.1629 - acc: 0.923 - ETA: 1s - loss: 0.1630 - acc: 0.923 - ETA: 1s - loss: 0.1627 - acc: 0.923 - ETA: 1s - loss: 0.1626 - acc: 0.923 - ETA: 1s - loss: 0.1627 - acc: 0.923 - ETA: 1s - loss: 0.1627 - acc: 0.923 - ETA: 1s - loss: 0.1628 - acc: 0.923 - ETA: 1s - loss: 0.1624 - acc: 0.924 - ETA: 1s - loss: 0.1622 - acc: 0.924 - ETA: 1s - loss: 0.1619 - acc: 0.924 - ETA: 1s - loss: 0.1615 - acc: 0.924 - ETA: 1s - loss: 0.1615 - acc: 0.924 - ETA: 1s - loss: 0.1615 - acc: 0.924 - ETA: 1s - loss: 0.1619 - acc: 0.924 - ETA: 0s - loss: 0.1617 - acc: 0.924 - ETA: 0s - loss: 0.1617 - acc: 0.924 - ETA: 0s - loss: 0.1621 - acc: 0.923 - ETA: 0s - loss: 0.1619 - acc: 0.924 - ETA: 0s - loss: 0.1621 - acc: 0.923 - ETA: 0s - loss: 0.1617 - acc: 0.924 - ETA: 0s - loss: 0.1613 - acc: 0.924 - ETA: 0s - loss: 0.1612 - acc: 0.924 - ETA: 0s - loss: 0.1610 - acc: 0.924 - ETA: 0s - loss: 0.1606 - acc: 0.924 - ETA: 0s - loss: 0.1608 - acc: 0.924 - ETA: 0s - loss: 0.1604 - acc: 0.924 - ETA: 0s - loss: 0.1604 - acc: 0.924 - ETA: 0s - loss: 0.1603 - acc: 0.924 - ETA: 0s - loss: 0.1599 - acc: 0.925 - ETA: 0s - loss: 0.1596 - acc: 0.925 - ETA: 0s - loss: 0.1593 - acc: 0.925 - ETA: 0s - loss: 0.1592 - acc: 0.925 - 3s 15us/sample - loss: 0.1593 - acc: 0.9254 - val_loss: 0.1388 - val_acc: 0.9360
# Epoch 4/10
# 193254/193254 [==============================] - ETA: 13s - loss: 0.1652 - acc: 0.91 - ETA: 2s - loss: 0.1681 - acc: 0.9188 - ETA: 2s - loss: 0.1635 - acc: 0.919 - ETA: 2s - loss: 0.1594 - acc: 0.923 - ETA: 2s - loss: 0.1576 - acc: 0.926 - ETA: 2s - loss: 0.1546 - acc: 0.927 - ETA: 2s - loss: 0.1547 - acc: 0.927 - ETA: 2s - loss: 0.1546 - acc: 0.927 - ETA: 2s - loss: 0.1548 - acc: 0.928 - ETA: 2s - loss: 0.1534 - acc: 0.929 - ETA: 2s - loss: 0.1540 - acc: 0.929 - ETA: 1s - loss: 0.1539 - acc: 0.929 - ETA: 1s - loss: 0.1533 - acc: 0.930 - ETA: 1s - loss: 0.1523 - acc: 0.930 - ETA: 1s - loss: 0.1515 - acc: 0.930 - ETA: 1s - loss: 0.1509 - acc: 0.931 - ETA: 1s - loss: 0.1522 - acc: 0.930 - ETA: 1s - loss: 0.1522 - acc: 0.930 - ETA: 1s - loss: 0.1524 - acc: 0.930 - ETA: 1s - loss: 0.1528 - acc: 0.930 - ETA: 1s - loss: 0.1528 - acc: 0.929 - ETA: 1s - loss: 0.1525 - acc: 0.929 - ETA: 1s - loss: 0.1518 - acc: 0.929 - ETA: 1s - loss: 0.1519 - acc: 0.929 - ETA: 1s - loss: 0.1525 - acc: 0.929 - ETA: 1s - loss: 0.1520 - acc: 0.929 - ETA: 1s - loss: 0.1519 - acc: 0.929 - ETA: 1s - loss: 0.1517 - acc: 0.929 - ETA: 1s - loss: 0.1515 - acc: 0.929 - ETA: 1s - loss: 0.1515 - acc: 0.929 - ETA: 0s - loss: 0.1511 - acc: 0.930 - ETA: 0s - loss: 0.1508 - acc: 0.930 - ETA: 0s - loss: 0.1507 - acc: 0.930 - ETA: 0s - loss: 0.1509 - acc: 0.930 - ETA: 0s - loss: 0.1507 - acc: 0.930 - ETA: 0s - loss: 0.1510 - acc: 0.930 - ETA: 0s - loss: 0.1513 - acc: 0.930 - ETA: 0s - loss: 0.1512 - acc: 0.930 - ETA: 0s - loss: 0.1513 - acc: 0.930 - ETA: 0s - loss: 0.1517 - acc: 0.929 - ETA: 0s - loss: 0.1515 - acc: 0.930 - ETA: 0s - loss: 0.1514 - acc: 0.930 - ETA: 0s - loss: 0.1514 - acc: 0.930 - ETA: 0s - loss: 0.1512 - acc: 0.930 - ETA: 0s - loss: 0.1510 - acc: 0.930 - ETA: 0s - loss: 0.1509 - acc: 0.930 - ETA: 0s - loss: 0.1508 - acc: 0.930 - ETA: 0s - loss: 0.1509 - acc: 0.930 - ETA: 0s - loss: 0.1510 - acc: 0.930 - 3s 15us/sample - loss: 0.1508 - acc: 0.9309 - val_loss: 0.1314 - val_acc: 0.9414
# Epoch 5/10
# 193254/193254 [==============================] - ETA: 11s - loss: 0.2202 - acc: 0.91 - ETA: 2s - loss: 0.1427 - acc: 0.9368 - ETA: 2s - loss: 0.1467 - acc: 0.934 - ETA: 2s - loss: 0.1496 - acc: 0.932 - ETA: 2s - loss: 0.1516 - acc: 0.932 - ETA: 2s - loss: 0.1504 - acc: 0.933 - ETA: 2s - loss: 0.1513 - acc: 0.932 - ETA: 2s - loss: 0.1501 - acc: 0.932 - ETA: 2s - loss: 0.1498 - acc: 0.933 - ETA: 2s - loss: 0.1492 - acc: 0.933 - ETA: 1s - loss: 0.1479 - acc: 0.933 - ETA: 1s - loss: 0.1478 - acc: 0.933 - ETA: 1s - loss: 0.1479 - acc: 0.933 - ETA: 1s - loss: 0.1480 - acc: 0.933 - ETA: 1s - loss: 0.1473 - acc: 0.933 - ETA: 1s - loss: 0.1476 - acc: 0.933 - ETA: 1s - loss: 0.1469 - acc: 0.933 - ETA: 1s - loss: 0.1472 - acc: 0.933 - ETA: 1s - loss: 0.1466 - acc: 0.933 - ETA: 1s - loss: 0.1467 - acc: 0.933 - ETA: 1s - loss: 0.1464 - acc: 0.933 - ETA: 1s - loss: 0.1461 - acc: 0.934 - ETA: 1s - loss: 0.1459 - acc: 0.933 - ETA: 1s - loss: 0.1459 - acc: 0.933 - ETA: 1s - loss: 0.1461 - acc: 0.933 - ETA: 1s - loss: 0.1466 - acc: 0.933 - ETA: 1s - loss: 0.1466 - acc: 0.933 - ETA: 1s - loss: 0.1466 - acc: 0.933 - ETA: 1s - loss: 0.1461 - acc: 0.933 - ETA: 0s - loss: 0.1463 - acc: 0.933 - ETA: 0s - loss: 0.1464 - acc: 0.933 - ETA: 0s - loss: 0.1463 - acc: 0.933 - ETA: 0s - loss: 0.1464 - acc: 0.933 - ETA: 0s - loss: 0.1465 - acc: 0.933 - ETA: 0s - loss: 0.1464 - acc: 0.933 - ETA: 0s - loss: 0.1462 - acc: 0.933 - ETA: 0s - loss: 0.1462 - acc: 0.933 - ETA: 0s - loss: 0.1461 - acc: 0.933 - ETA: 0s - loss: 0.1458 - acc: 0.934 - ETA: 0s - loss: 0.1459 - acc: 0.933 - ETA: 0s - loss: 0.1459 - acc: 0.934 - ETA: 0s - loss: 0.1457 - acc: 0.934 - ETA: 0s - loss: 0.1456 - acc: 0.934 - ETA: 0s - loss: 0.1456 - acc: 0.934 - ETA: 0s - loss: 0.1456 - acc: 0.934 - ETA: 0s - loss: 0.1456 - acc: 0.934 - ETA: 0s - loss: 0.1455 - acc: 0.934 - ETA: 0s - loss: 0.1456 - acc: 0.934 - ETA: 0s - loss: 0.1456 - acc: 0.934 - 3s 15us/sample - loss: 0.1454 - acc: 0.9345 - val_loss: 0.1296 - val_acc: 0.9417
# Epoch 6/10
# 193254/193254 [==============================] - ETA: 11s - loss: 0.1872 - acc: 0.93 - ETA: 2s - loss: 0.1516 - acc: 0.9302 - ETA: 2s - loss: 0.1536 - acc: 0.930 - ETA: 2s - loss: 0.1490 - acc: 0.931 - ETA: 2s - loss: 0.1453 - acc: 0.931 - ETA: 2s - loss: 0.1462 - acc: 0.932 - ETA: 2s - loss: 0.1465 - acc: 0.932 - ETA: 2s - loss: 0.1454 - acc: 0.933 - ETA: 2s - loss: 0.1445 - acc: 0.934 - ETA: 2s - loss: 0.1447 - acc: 0.934 - ETA: 2s - loss: 0.1449 - acc: 0.934 - ETA: 1s - loss: 0.1447 - acc: 0.934 - ETA: 1s - loss: 0.1441 - acc: 0.934 - ETA: 1s - loss: 0.1436 - acc: 0.934 - ETA: 1s - loss: 0.1438 - acc: 0.934 - ETA: 1s - loss: 0.1443 - acc: 0.934 - ETA: 1s - loss: 0.1441 - acc: 0.934 - ETA: 1s - loss: 0.1435 - acc: 0.934 - ETA: 1s - loss: 0.1434 - acc: 0.935 - ETA: 1s - loss: 0.1433 - acc: 0.935 - ETA: 1s - loss: 0.1432 - acc: 0.934 - ETA: 1s - loss: 0.1433 - acc: 0.934 - ETA: 1s - loss: 0.1429 - acc: 0.935 - ETA: 1s - loss: 0.1431 - acc: 0.935 - ETA: 1s - loss: 0.1429 - acc: 0.935 - ETA: 1s - loss: 0.1427 - acc: 0.935 - ETA: 1s - loss: 0.1426 - acc: 0.935 - ETA: 1s - loss: 0.1426 - acc: 0.935 - ETA: 1s - loss: 0.1425 - acc: 0.935 - ETA: 0s - loss: 0.1425 - acc: 0.935 - ETA: 0s - loss: 0.1425 - acc: 0.935 - ETA: 0s - loss: 0.1421 - acc: 0.935 - ETA: 0s - loss: 0.1419 - acc: 0.936 - ETA: 0s - loss: 0.1416 - acc: 0.936 - ETA: 0s - loss: 0.1416 - acc: 0.936 - ETA: 0s - loss: 0.1414 - acc: 0.936 - ETA: 0s - loss: 0.1412 - acc: 0.936 - ETA: 0s - loss: 0.1414 - acc: 0.936 - ETA: 0s - loss: 0.1412 - acc: 0.936 - ETA: 0s - loss: 0.1413 - acc: 0.936 - ETA: 0s - loss: 0.1415 - acc: 0.936 - ETA: 0s - loss: 0.1414 - acc: 0.936 - ETA: 0s - loss: 0.1413 - acc: 0.936 - ETA: 0s - loss: 0.1415 - acc: 0.936 - ETA: 0s - loss: 0.1414 - acc: 0.936 - ETA: 0s - loss: 0.1412 - acc: 0.936 - ETA: 0s - loss: 0.1413 - acc: 0.936 - ETA: 0s - loss: 0.1413 - acc: 0.936 - ETA: 0s - loss: 0.1413 - acc: 0.936 - 3s 15us/sample - loss: 0.1413 - acc: 0.9366 - val_loss: 0.1288 - val_acc: 0.9416
# Epoch 7/10
# 193254/193254 [==============================] - ETA: 11s - loss: 0.1605 - acc: 0.92 - ETA: 3s - loss: 0.1510 - acc: 0.9349 - ETA: 2s - loss: 0.1490 - acc: 0.934 - ETA: 2s - loss: 0.1431 - acc: 0.937 - ETA: 2s - loss: 0.1410 - acc: 0.938 - ETA: 2s - loss: 0.1384 - acc: 0.939 - ETA: 2s - loss: 0.1379 - acc: 0.939 - ETA: 2s - loss: 0.1393 - acc: 0.939 - ETA: 2s - loss: 0.1381 - acc: 0.939 - ETA: 2s - loss: 0.1391 - acc: 0.938 - ETA: 1s - loss: 0.1395 - acc: 0.938 - ETA: 1s - loss: 0.1392 - acc: 0.938 - ETA: 1s - loss: 0.1401 - acc: 0.937 - ETA: 1s - loss: 0.1406 - acc: 0.937 - ETA: 1s - loss: 0.1401 - acc: 0.937 - ETA: 1s - loss: 0.1404 - acc: 0.937 - ETA: 1s - loss: 0.1404 - acc: 0.937 - ETA: 1s - loss: 0.1408 - acc: 0.937 - ETA: 1s - loss: 0.1403 - acc: 0.937 - ETA: 1s - loss: 0.1401 - acc: 0.937 - ETA: 1s - loss: 0.1402 - acc: 0.937 - ETA: 1s - loss: 0.1399 - acc: 0.937 - ETA: 1s - loss: 0.1404 - acc: 0.937 - ETA: 1s - loss: 0.1407 - acc: 0.937 - ETA: 1s - loss: 0.1406 - acc: 0.937 - ETA: 1s - loss: 0.1408 - acc: 0.937 - ETA: 1s - loss: 0.1406 - acc: 0.937 - ETA: 1s - loss: 0.1405 - acc: 0.937 - ETA: 1s - loss: 0.1407 - acc: 0.937 - ETA: 0s - loss: 0.1408 - acc: 0.937 - ETA: 0s - loss: 0.1408 - acc: 0.936 - ETA: 0s - loss: 0.1408 - acc: 0.937 - ETA: 0s - loss: 0.1406 - acc: 0.937 - ETA: 0s - loss: 0.1406 - acc: 0.937 - ETA: 0s - loss: 0.1408 - acc: 0.937 - ETA: 0s - loss: 0.1409 - acc: 0.937 - ETA: 0s - loss: 0.1408 - acc: 0.937 - ETA: 0s - loss: 0.1406 - acc: 0.937 - ETA: 0s - loss: 0.1407 - acc: 0.937 - ETA: 0s - loss: 0.1405 - acc: 0.937 - ETA: 0s - loss: 0.1402 - acc: 0.937 - ETA: 0s - loss: 0.1400 - acc: 0.937 - ETA: 0s - loss: 0.1401 - acc: 0.937 - ETA: 0s - loss: 0.1401 - acc: 0.937 - ETA: 0s - loss: 0.1403 - acc: 0.937 - ETA: 0s - loss: 0.1399 - acc: 0.937 - ETA: 0s - loss: 0.1399 - acc: 0.937 - ETA: 0s - loss: 0.1398 - acc: 0.937 - 3s 14us/sample - loss: 0.1400 - acc: 0.9377 - val_loss: 0.1253 - val_acc: 0.9445
# Epoch 8/10
# 193254/193254 [==============================] - ETA: 13s - loss: 0.1359 - acc: 0.95 - ETA: 2s - loss: 0.1405 - acc: 0.9400 - ETA: 2s - loss: 0.1419 - acc: 0.939 - ETA: 2s - loss: 0.1405 - acc: 0.939 - ETA: 2s - loss: 0.1409 - acc: 0.939 - ETA: 2s - loss: 0.1401 - acc: 0.939 - ETA: 2s - loss: 0.1375 - acc: 0.940 - ETA: 2s - loss: 0.1373 - acc: 0.940 - ETA: 2s - loss: 0.1371 - acc: 0.940 - ETA: 1s - loss: 0.1375 - acc: 0.940 - ETA: 1s - loss: 0.1382 - acc: 0.939 - ETA: 1s - loss: 0.1383 - acc: 0.939 - ETA: 1s - loss: 0.1378 - acc: 0.939 - ETA: 1s - loss: 0.1385 - acc: 0.939 - ETA: 1s - loss: 0.1385 - acc: 0.939 - ETA: 1s - loss: 0.1384 - acc: 0.939 - ETA: 1s - loss: 0.1379 - acc: 0.939 - ETA: 1s - loss: 0.1377 - acc: 0.939 - ETA: 1s - loss: 0.1381 - acc: 0.939 - ETA: 1s - loss: 0.1387 - acc: 0.938 - ETA: 1s - loss: 0.1387 - acc: 0.938 - ETA: 1s - loss: 0.1390 - acc: 0.938 - ETA: 1s - loss: 0.1392 - acc: 0.938 - ETA: 1s - loss: 0.1390 - acc: 0.938 - ETA: 1s - loss: 0.1386 - acc: 0.938 - ETA: 1s - loss: 0.1384 - acc: 0.938 - ETA: 1s - loss: 0.1388 - acc: 0.938 - ETA: 1s - loss: 0.1389 - acc: 0.938 - ETA: 0s - loss: 0.1388 - acc: 0.938 - ETA: 0s - loss: 0.1386 - acc: 0.938 - ETA: 0s - loss: 0.1382 - acc: 0.938 - ETA: 0s - loss: 0.1382 - acc: 0.938 - ETA: 0s - loss: 0.1381 - acc: 0.938 - ETA: 0s - loss: 0.1381 - acc: 0.938 - ETA: 0s - loss: 0.1383 - acc: 0.938 - ETA: 0s - loss: 0.1382 - acc: 0.938 - ETA: 0s - loss: 0.1383 - acc: 0.938 - ETA: 0s - loss: 0.1383 - acc: 0.938 - ETA: 0s - loss: 0.1381 - acc: 0.938 - ETA: 0s - loss: 0.1386 - acc: 0.938 - ETA: 0s - loss: 0.1384 - acc: 0.938 - ETA: 0s - loss: 0.1380 - acc: 0.938 - ETA: 0s - loss: 0.1378 - acc: 0.938 - ETA: 0s - loss: 0.1377 - acc: 0.938 - ETA: 0s - loss: 0.1377 - acc: 0.938 - ETA: 0s - loss: 0.1376 - acc: 0.938 - ETA: 0s - loss: 0.1376 - acc: 0.938 - ETA: 0s - loss: 0.1377 - acc: 0.938 - 3s 15us/sample - loss: 0.1376 - acc: 0.9385 - val_loss: 0.1243 - val_acc: 0.9450
# Epoch 9/10
# 193254/193254 [==============================] - ETA: 15s - loss: 0.0751 - acc: 0.97 - ETA: 2s - loss: 0.1243 - acc: 0.9424 - ETA: 2s - loss: 0.1301 - acc: 0.939 - ETA: 2s - loss: 0.1381 - acc: 0.937 - ETA: 2s - loss: 0.1368 - acc: 0.937 - ETA: 2s - loss: 0.1339 - acc: 0.939 - ETA: 2s - loss: 0.1352 - acc: 0.939 - ETA: 2s - loss: 0.1350 - acc: 0.939 - ETA: 2s - loss: 0.1350 - acc: 0.939 - ETA: 2s - loss: 0.1342 - acc: 0.939 - ETA: 1s - loss: 0.1352 - acc: 0.939 - ETA: 1s - loss: 0.1347 - acc: 0.939 - ETA: 1s - loss: 0.1353 - acc: 0.938 - ETA: 1s - loss: 0.1353 - acc: 0.939 - ETA: 1s - loss: 0.1359 - acc: 0.938 - ETA: 1s - loss: 0.1366 - acc: 0.938 - ETA: 1s - loss: 0.1374 - acc: 0.938 - ETA: 1s - loss: 0.1375 - acc: 0.938 - ETA: 1s - loss: 0.1373 - acc: 0.938 - ETA: 1s - loss: 0.1369 - acc: 0.938 - ETA: 1s - loss: 0.1370 - acc: 0.939 - ETA: 1s - loss: 0.1367 - acc: 0.939 - ETA: 1s - loss: 0.1367 - acc: 0.939 - ETA: 1s - loss: 0.1365 - acc: 0.939 - ETA: 1s - loss: 0.1365 - acc: 0.939 - ETA: 1s - loss: 0.1365 - acc: 0.939 - ETA: 1s - loss: 0.1367 - acc: 0.939 - ETA: 0s - loss: 0.1368 - acc: 0.939 - ETA: 0s - loss: 0.1365 - acc: 0.939 - ETA: 0s - loss: 0.1365 - acc: 0.939 - ETA: 0s - loss: 0.1365 - acc: 0.939 - ETA: 0s - loss: 0.1367 - acc: 0.939 - ETA: 0s - loss: 0.1368 - acc: 0.939 - ETA: 0s - loss: 0.1367 - acc: 0.939 - ETA: 0s - loss: 0.1366 - acc: 0.939 - ETA: 0s - loss: 0.1364 - acc: 0.939 - ETA: 0s - loss: 0.1364 - acc: 0.939 - ETA: 0s - loss: 0.1365 - acc: 0.939 - ETA: 0s - loss: 0.1366 - acc: 0.939 - ETA: 0s - loss: 0.1366 - acc: 0.939 - ETA: 0s - loss: 0.1368 - acc: 0.939 - ETA: 0s - loss: 0.1365 - acc: 0.939 - ETA: 0s - loss: 0.1366 - acc: 0.939 - ETA: 0s - loss: 0.1368 - acc: 0.938 - ETA: 0s - loss: 0.1367 - acc: 0.938 - ETA: 0s - loss: 0.1367 - acc: 0.938 - ETA: 0s - loss: 0.1365 - acc: 0.938 - 3s 14us/sample - loss: 0.1365 - acc: 0.9388 - val_loss: 0.1239 - val_acc: 0.9445
# Epoch 10/10
# 193254/193254 [==============================] - ETA: 13s - loss: 0.1145 - acc: 0.95 - ETA: 2s - loss: 0.1267 - acc: 0.9419 - ETA: 2s - loss: 0.1306 - acc: 0.941 - ETA: 2s - loss: 0.1328 - acc: 0.939 - ETA: 2s - loss: 0.1345 - acc: 0.939 - ETA: 2s - loss: 0.1366 - acc: 0.938 - ETA: 2s - loss: 0.1348 - acc: 0.939 - ETA: 2s - loss: 0.1345 - acc: 0.940 - ETA: 1s - loss: 0.1355 - acc: 0.939 - ETA: 1s - loss: 0.1355 - acc: 0.939 - ETA: 1s - loss: 0.1368 - acc: 0.939 - ETA: 1s - loss: 0.1367 - acc: 0.939 - ETA: 1s - loss: 0.1364 - acc: 0.939 - ETA: 1s - loss: 0.1366 - acc: 0.939 - ETA: 1s - loss: 0.1366 - acc: 0.939 - ETA: 1s - loss: 0.1369 - acc: 0.939 - ETA: 1s - loss: 0.1366 - acc: 0.939 - ETA: 1s - loss: 0.1361 - acc: 0.939 - ETA: 1s - loss: 0.1365 - acc: 0.938 - ETA: 1s - loss: 0.1363 - acc: 0.938 - ETA: 1s - loss: 0.1362 - acc: 0.939 - ETA: 1s - loss: 0.1360 - acc: 0.938 - ETA: 1s - loss: 0.1356 - acc: 0.939 - ETA: 1s - loss: 0.1354 - acc: 0.939 - ETA: 1s - loss: 0.1353 - acc: 0.939 - ETA: 1s - loss: 0.1347 - acc: 0.939 - ETA: 1s - loss: 0.1348 - acc: 0.939 - ETA: 0s - loss: 0.1350 - acc: 0.939 - ETA: 0s - loss: 0.1351 - acc: 0.939 - ETA: 0s - loss: 0.1355 - acc: 0.939 - ETA: 0s - loss: 0.1357 - acc: 0.939 - ETA: 0s - loss: 0.1362 - acc: 0.939 - ETA: 0s - loss: 0.1359 - acc: 0.939 - ETA: 0s - loss: 0.1358 - acc: 0.939 - ETA: 0s - loss: 0.1357 - acc: 0.939 - ETA: 0s - loss: 0.1358 - acc: 0.939 - ETA: 0s - loss: 0.1356 - acc: 0.939 - ETA: 0s - loss: 0.1356 - acc: 0.939 - ETA: 0s - loss: 0.1357 - acc: 0.939 - ETA: 0s - loss: 0.1357 - acc: 0.939 - ETA: 0s - loss: 0.1356 - acc: 0.939 - ETA: 0s - loss: 0.1355 - acc: 0.939 - ETA: 0s - loss: 0.1355 - acc: 0.939 - ETA: 0s - loss: 0.1358 - acc: 0.939 - ETA: 0s - loss: 0.1355 - acc: 0.939 - ETA: 0s - loss: 0.1354 - acc: 0.939 - ETA: 0s - loss: 0.1354 - acc: 0.939 - 3s 14us/sample - loss: 0.1354 - acc: 0.9395 - val_loss: 0.1226 - val_acc: 0.9465

# %%
ypred=classifier.predict(X_test)
ypred=(ypred>0.5)
ypred
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
from sklearn.metrics import f1_score
score2=f1_score(Y_test, y_pred)
score2
# Out:
# 0.9189409923092628

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,ypred)
cm
# Out:
# array([[21511,  1729],
#        [ 1718, 39461]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accs2=accuracy_score(Y_test,ypred)
accs2
# Out:
# 0.9464909421133516

# %%
from prettytable import PrettyTable
x = PrettyTable()
x.field_names = ["Model", "Accuracy"]
x.add_row(["Logistic Regression", "{0:.4}".format(accs)])
x.add_row(["Linear SVM", "{0:.4}".format(accs1)])
x.add_row(["Neural Network", "{0:.4}".format(accs2)])
print(x)
# Out:
# +---------------------+----------+
# |        Model        | Accuracy |
# +---------------------+----------+
# | Logistic Regression |  0.8891  |
# |      Linear SVM     |  0.8891  |
# |    Neural Network   |  0.9465  |
# +---------------------+----------+
